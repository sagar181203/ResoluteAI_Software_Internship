# %% [markdown]
# LOADING IMAGE WITH OPEN-CV

# %%
# openCV  works on BGR
import cv2
import numpy as np
from matplotlib import pyplot as plt

# converting img to the grayscale image 
img = cv2.imread('watch.jpg',cv2.IMREAD_GRAYSCALE) # Even we can use 0 instead of cv2.IMREAD_GRAYSCALE
                                                   # IMREAD_COLOR = 1
                                                   # IMREAD_UNCHANGED= -1

cv2.imshow('image',img) # to show the window with the title image 
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# matplotlib works on RGB
import cv2
import numpy as np
from matplotlib import pyplot as plt

# converting img to the grayscale image 
img = cv2.imread('watch.jpg',cv2.IMREAD_GRAYSCALE)

plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.plot([200,300,400],[100,200,300],'c', linewidth=5)
plt.show()                      #  we can handle the linewidth as we need 

# To save it we can use this
# cv2.imwrite('gray.png',img)

# %% [markdown]
# LOADING VIDEO SOURCE

# %%
import cv2
import numpy as nm 
cap=cv2.VideoCapture(0) # 0 for the first web-cam to respond  
                        # 1 for the second active web-cam to respond
fourcc=cv2.VideoWriter_fourcc(*'XVID')
out=cv2.VideoWriter('output.mp4',fourcc,20.0,(640,480))
while True:
    ret,frame=cap.read()
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY) # conversion of BGR to Gray
    out.write(frame)
    cv2.imshow('COLOR FRAME ',frame) # For the Color or Normal frame 
    cv2.imshow('GRAY FRAME ',gray)   # To Display the the Gray Frame 

    if cv2.waitKey(1)& 0xFF==ord('q'):
        break
cap.release()
out.release()
cv2.destroyAllWindows()

# %% [markdown]
# DRAWING AND WRITING ON IMAGE

# %%
# To Draw
import cv2
import numpy as np
img=cv2.imread('watch.jpg',cv2.IMREAD_COLOR)

# To draw the line 
cv2.line(img,(0,0),(150,150),(255,255,255),15) # BGR    -----------(B G R) 
                                                        # for Black (0,0,0)
                                                        # for White (255 255 255)
                                                        # for Blue(255,0,0)
                                                        # for Green(0,255,0) 
                                                        # for Red (0,0, 255)

# TO draw the rectangle
cv2.rectangle(img,(50,25),(200,150),(0,255,0),5)
# dest , top left co-ordinates, Bottom right co-ordinates, color  ,width
 
# To Draw the Circle
cv2.circle(img,(100,63),55,(0,0,255),-1) # -1 width as to fill the circle 
 # dest , Centre , radius ,color , width 

# To  Draw the polygon
pts=np.array([[10, 5],[20, 30],[70,20],[50,10]],np.int32) 
pts=pts.reshape(-1 ,1, 2)
cv2.polylines(img,[pts],True,(0,255,255),3)
# dest, points, true for if want to connect last point or not 

# Drawing or Writing the Text on Image 
font=cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,'Sagar',(0,130),font, 1,(255,255,0),2,cv2.LINE_AA)
# dest, Text, starting point, What the font , Size ,color, thickness ,anti-aliasing 

cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# IMAGE OPERATION

# %%
# Note : Feed color image or input then conversion to gray-scale
# And then perform the analysis to finding the coordinates 
import cv2
import numpy as np
img=cv2.imread('watch.jpg', cv2.IMREAD_COLOR)
img[55,55]=[255,255,255] # converted to white pixel
px=img[55,55] # for pixel of the image 
print(px) 

# ROI : Region of image (its just a sub-image of a image basically )
# roi=img[100:150,100:150] #(uncomment to check the region of the pixel)
# print(roi)

img[100:150,100:150]=[255,255,255] # conversion of region to a white Square'

watch_face =img[37:111, 107: 194]
img[0:74,0:87]= watch_face

cv2.imshow('Image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [255 255 255]

# %% [markdown]
# IMAGE ARITHMETICS AND LOGIC

# %%
# Both image must be of same size  
import cv2 
import numpy as np

img1=cv2.imread('3D-Matplotlib.png')
img2=cv2.imread('mainsvmimage.png')

# check the pixel of image 
# px1=img1[55,55]
# print (px1)
# px2=img1[55,55]
# print (px2)

#Built-in Add method Syntax in openCV
add = cv2.add(img1,img2)
cv2.imshow("Add",add)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2 
import numpy as np

img1=cv2.imread('3D-Matplotlib.png')
img2=cv2.imread('mainsvmimage.png')

# check the pixel of image 
# px1=img1[55,55]
# print (px1)
# px2=img1[55,55]
# print (px2)

#Built-in Add method Syntax in openCV
add = cv2.add(img1/2,img2/2)
cv2.imshow("Add",add)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2 
import numpy as np

img1=cv2.imread('3D-Matplotlib.png')
img2=cv2.imread('mainlogo.png')
# img2=cv2.imread('apple.png') # uncomment to check for Apple logo

rows, cols, channels =img2.shape 
roi=img1[0:rows,0:cols]

img2gray=cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
ret, mask=cv2.threshold(img2gray, 220,255,cv2.THRESH_BINARY_INV)
# dest, threshold value(220) , more than (220) converted to(255)
# less than (220) will convert to black (0)

# invisible of mask part 
mask_inv= cv2.bitwise_not(mask)

# background of img1 
img1_bg=cv2.bitwise_and(roi, roi, mask=mask_inv)
# Foreground of img2
img2_fg=cv2.bitwise_and(img2, img2, mask=mask)



dst= cv2.add(img1_bg,img2_fg)
img1[0:rows, 0:cols]=dst

cv2.imshow("result",img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# THRESHOLDING

# %%
# Note : use Thresholding as per the situation of problem 
# After Simplifying to grayscale image we further simplifies it with Threshold value 
# basic level it into either 0 or 1 also can be gradient  
import cv2
import numpy as np
img =cv2.imread ('bookpage.jpg')
retval , threshold =cv2.threshold(img, 12,255,cv2.THRESH_BINARY)
#  (12-255)
cv2.imshow('Original',img)
cv2.imshow('threshold',threshold)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
img =cv2.imread ('bookpage.jpg')
retval , threshold =cv2.threshold(img, 12,255,cv2.THRESH_BINARY)

# conversion of grayscale and go for the threshold2  which applies on grayscaled 
grayscaled =cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
retval2 , threshold2 =cv2.threshold(grayscaled, 12,255,cv2.THRESH_BINARY)
cv2.imshow('Original',img)
cv2.imshow('threshold',threshold)
cv2.imshow('threshold2',threshold2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Gaussian Adaptive Threshold 
import cv2
import numpy as np
img =cv2.imread ('bookpage.jpg')
retval , threshold =cv2.threshold(img, 12,255,cv2.THRESH_BINARY)

grayscaled =cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
retval2 , threshold2 =cv2.threshold(grayscaled, 12,255,cv2.THRESH_BINARY)

# Gausssian Threshold 
gaus=cv2.adaptiveThreshold(grayscaled,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,115,1)

cv2.imshow('Original',img)
cv2.imshow('threshold',threshold)
cv2.imshow('threshold2',threshold2)
cv2.imshow('Gaussian',gaus)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# otsu Threshold 
import cv2
import numpy as np
img =cv2.imread ('bookpage.jpg')
retval , threshold =cv2.threshold(img, 12,255,cv2.THRESH_BINARY)

grayscaled =cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
retval2 , threshold2 =cv2.threshold(grayscaled, 12,255,cv2.THRESH_BINARY)
retval2 , otsu =cv2.threshold(grayscaled, 125,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)


cv2.imshow('Original',img)
cv2.imshow('threshold',threshold)
cv2.imshow('threshold2',threshold2)
cv2.imshow('OTSU',otsu)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# COLOR FILTERING

# %%
import cv2                         
import numpy as np
cap=cv2.VideoCapture(0)
while True:
    _,frame=cap.read()
    # instead of return _ used
    # another way to define color
    hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)   # hue Saturation value

    lower_red=np.array([150,150,50])
    upper_red=np.array([180, 255,150])

# we can use these range for following colors --------

# For Green:
# Lower range: [40, 100, 100]
# Upper range: [70, 255, 255]

# For Blue:
# Lower range: [110, 100, 100]
# Upper range: [130, 255, 255]

# For White:
# Lower range: [0, 0, 200]
# Upper range: [180, 30, 255]

# For Black:
# Lower range: [0, 0, 0]
# Upper range: [180, 255, 30]

    mask = cv2.inRange(hsv, lower_red, upper_red)
    result = cv2.bitwise_and(frame,frame, mask= mask)

    cv2.imshow('frame',frame)
    cv2.imshow('mask',mask)
    cv2.imshow('result',result)
    
    if cv2.waitKey(1)& 0xFF==ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# BLURRING & SMOOTHING

# %%
import cv2                         
import numpy as np
cap=cv2.VideoCapture(0)
while True:
    _,frame=cap.read()
    # instead of return _ used
    # another way to define color
    hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)   # hue Saturation value

    lower_red=np.array([150,150,50])
    upper_red=np.array([180,255,150])

    mask = cv2.inRange(hsv, lower_red, upper_red)
    result = cv2.bitwise_and(frame,frame, mask= mask)

    # numpy ones list of ones and datatype numpy float32 devide by the multiplication or average 
    #15x15
    kernel=np.ones((15,15),np.float32)/225
    smoothed=cv2.filter2D(result,-1,kernel)


    #  Different Blurring versions 
    #  Gaussian Blurring (15x15)
    blur = cv2.GaussianBlur(result,(15,15),0)

    # Median Blur
    median = cv2.medianBlur(result,15) # size 15

    # Bilateral Blur (75x75)
    bilateral = cv2.bilateralFilter(result ,15,75,75)

    
    cv2.imshow('frame',frame)
    cv2.imshow('result',result)
    cv2.imshow('Smoothed', smoothed)
    cv2.imshow('Gaussian Blurring',blur)
    cv2.imshow('Median Blur',median)
    cv2.imshow('Bilateral Blur',bilateral)
    
    if cv2.waitKey(1)& 0xFF==ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# MORPHOLOGICAL TRANSFORMATION

# %%
import cv2                         
import numpy as np
cap=cv2.VideoCapture(0)
while True:
    _,frame=cap.read()
    # instead of return _ used
    # another way to define color
    hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)   # hue Saturation value

    lower_red=np.array([150,150,50])
    upper_red=np.array([180,255,150])

    mask = cv2.inRange(hsv, lower_red, upper_red)
    result = cv2.bitwise_and(frame,frame, mask= mask)

    # Erosion and Dilation are morphological image processing operations.
    # use for :------
    # Removing Noise
    # Identify intensity bumps or holes in the picture.
    # Isolation of individual elements and joining disparate elements in image.
    kernel= np.ones((5,5),np.uint8)
    erosion=cv2.erode(mask,kernel,iterations=1)
    dilation=cv2.dilate(mask,kernel,iterations=1)

    opening=cv2.morphologyEx(mask,cv2.MORPH_OPEN,kernel)
    closing=cv2.morphologyEx(mask,cv2.MORPH_CLOSE,kernel)

    cv2.imshow('frame',frame)
    cv2.imshow('result',result)
    cv2.imshow('Erosion',erosion)
    cv2.imshow('Dilation',dilation)
    cv2.imshow('Opening',opening)
    cv2.imshow('Closing',closing)

    if cv2.waitKey(1)& 0xFF==ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# EDGE DETECTION & GRADIENTS

# %%
import cv2
cap=cv2.VideoCapture(0)

while True:
    _, frame=cap.read()

    laplacian=cv2.Laplacian(frame,cv2.CV_64F)# cV_64F data type

    sobelx=cv2.Sobel(frame,cv2.CV_64F,1,0,ksize=5) # (1,0)=x,y
    sobely=cv2.Sobel(frame,cv2.CV_64F,0,1,ksize=5) 

    # Canny Edge detection
    edgee=cv2.Canny(frame,100,200) # built-in Edge 

    cv2.imshow('Frame',frame)
    cv2.imshow('Laplacian',laplacian)
    cv2.imshow('Sobelx',sobelx)
    cv2.imshow('Sobely',sobely)
    cv2.imshow(' Canny Edge',edgee)

    if cv2.waitKey(1)& 0xFF==ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# TEMPLATE MATCHING

# %%
import cv2
import numpy as np
img_bgr=cv2.imread('Template.jpg')
img_gray=cv2.cvtColor(img_bgr,cv2.COLOR_BGR2GRAY)

template=cv2.imread('opencv-template-for-matching.jpg',0)
w,h=template.shape[::-1] #weidth and height 

res=cv2.matchTemplate(img_gray,template,cv2.TM_CCOEFF_NORMED)
threshold=0.8
loc=np.where(res>=threshold)

for pt in zip(*loc[::-1]):
    cv2.rectangle(img_bgr,pt,(pt[0]+w,pt[1]+h),(0,255,255),2)

cv2.imshow('Detected',img_bgr)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# GRAB-CUT FOREGROUND EXTRACTION

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread('sagar.jpg')
mask=np.zeros(img.shape[:2],np.uint8) # data type uint8 
#background Model
bgdModel=np.zeros((1,65),np.float64)
fgdModel=np.zeros((1,65),np.float64)

rect=(400,50,450,500)
# x :X-coordinate of the top-left corner of the rectangle
# y :Y-coordinate of the top-left corner of the rectangle
# w :Width of the rectangle
# h :Height of the rectangle
# rect = (x, y, w, h)

# Grab cut
cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)
mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img = img*mask2[:,:,np.newaxis]# slicing 

plt.imshow(img)
plt.colorbar()
plt.show()

# %% [markdown]
# CORNER DETECTION

# %%
# Can Use for ---
# Try to find all corners 
# Character Regonition
# Motion Tracking 

import cv2
import numpy as np

img=cv2.imread('corner.jpg')
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray=np.float32(gray) # conversion

corners=cv2.goodFeaturesToTrack(gray,50,0.01,10)# upto 100 corners ,quality,min distance between corners
corners=np.int0(corners)

for corner in corners:
    x,y =corner.ravel()
    cv2.circle(img,(x,y),3,255,-1) # 3:radius ,color, fill 
cv2.imshow('corner ',img) 
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# FEATURE MATCHING

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img1=cv2.imread('gita.jpg',0)
img2=cv2.imread('bhagwatGita.jpg',0)

orb = cv2.ORB_create()

# key-point 1 and 2
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)

# find the key points and their descriptors with the orb detector
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True) # bf matcher obj as bf

matches = bf.match(des1,des2) # sorting 
matches = sorted(matches, key = lambda x:x.distance)
img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:10],None, flags=2)
plt.imshow(img3)
plt.show()

# %% [markdown]
# MOG BACKGROUND REDUCTION

# %%
import cv2
import numpy as np
cap=cv2.VideoCapture('people-walking.mp4')
# cap=cv2.VideoCapture(0)
fgbg=cv2.createBackgroundSubtractorMOG2()

while True:
    ret,frame=cap.read()
    # new fore-ground mask
    fgmask=fgbg.apply(frame)

    cv2.imshow('Original_Frame ',frame)    
    cv2.imshow('fg ',fgmask) 
   

    if cv2.waitKey(30)& 0xFF==ord('q'):
        break 

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# Haar Cascade Object Detection

# %%
import cv2
import numpy as np

face_cascade=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade=cv2.CascadeClassifier('haarcascade_eye.xml')

# 
cap=cv2.VideoCapture(0)
while True:
    ret,img=cap.read()
    gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5) # depend on the size of image 

    for (x,y,w,h) in faces:
        # drawing the rectangle 
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
        # dest ,  starting point , ending point,(blue) color, width

        # Region Starting point ,Ending point
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        

        eyes = eye_cascade.detectMultiScale(roi_gray)# detect against gray
        for (ex,ey,ew,eh) in eyes:
             # drawing the rectangle around the eyes 
            cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2) # Color (Green)

    cv2.imshow('img',img)
    if cv2.waitKey(30)& 0xFF==ord('q'):
        break


cap.release()
cv2.destroyAllWindows()
